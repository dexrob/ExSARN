# %%
#!/usr/bin/env python
# coding: utf-8

'''
sample command: python T4_BT19_ae.py 
Individual training for BioTac data (full/partial data)
if -r=1, train with full data
if -r=2, train with half data
loss = classification loss + recon loss 
'''

# Import
import os,sys
import pickle
# import argparse
from datetime import datetime
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torchvision
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt

from vrae.lmu import CNNLMU
from vrae.tas_utils_bs import get_trainValLoader, get_testLoader

from vrae.visual import confusion_matrix_plot, tsne

import scipy.io as sio

# if running jupyter notebook
class Args:
    kfold = 0
    cuda = '0'
    rep = 0
    reduction = 1
    data_dir = 'data'
    data = 'B'
    w_r = 0.01
    w_c = 1
    if data == 'I':
        sequence_length = 75
        number_of_features = 60
        header = 'CNN'

    if data == 'B':
        sequence_length = 400
        number_of_features = 19
        header = None
        
args=Args()
print(args)

# # Parse argument
# parser = argparse.ArgumentParser()
# parser.add_argument("-i", "--rep", type=int, default=0, help='index of running repetition')
# parser.add_argument('--data_dir', type=str, required=True, help="DIR set in 'gh_download.sh' to store compiled_data")
# parser.add_argument("-k", "--kfold", type=int, default=0, help="kfold_number for loading data")
# parser.add_argument("-r", "--reduction", type=int, default=1, help="data reduction ratio for partial training")
# parser.add_argument("-c", "--cuda", default=0, help="index of cuda gpu to use")
# args = parser.parse_args()

def train(args, sequence_length, number_of_features, header):
    # Set hyper params
    args_data_dir = args.data_dir
    kfold_number = args.kfold
    data_reduction_ratio = args.reduction
    shuffle = True # set to False for partial training
    num_class = 20

    hidden_size = 90
    hidden_layer_depth = 1
    latent_length = 40
    batch_size = 32
    learning_rate = 0.0005
    n_epochs = 100 # TODO reset the parameter
    dropout_rate = 0.2
    cuda = True # options: True, False

    np.random.seed(1)
    torch.manual_seed(1)

    # Load data
    data_dir = os.path.join(args_data_dir, "compiled_data/")
    logDir = 'models_and_stats/'
    if_plot = False

    # model_name = 'BT19_ae_{}_wrI_{}_wC_{}_{}'.format(data_reduction_ratio, w_r, w_c, str(kfold_number))
    model_name = "test_indiv_B"

    if torch.cuda.is_available():
        device = torch.device("cuda:{}".format(args.cuda))
    else:
        device = torch.device('cpu')

    if args.reduction != 1:
        print("load {} kfold number, reduce data to {} folds, put to device: {}".format(args.kfold, args.reduction, device))
    else:
        print("load {} kfold number, train with full data, put to devide: {}".format(args.kfold, device))

    train_loader, val_loader, train_dataset, val_dataset = get_trainValLoader(data_dir, k=kfold_number, spike_ready=False, batch_size=batch_size, shuffle=shuffle)
    test_loader, test_dataset = get_testLoader(data_dir, spike_ready=False, batch_size=batch_size, shuffle=shuffle)

    # Initialize models
    model = CNNLMU(num_class=num_class,
                sequence_length=sequence_length,
                number_of_features = number_of_features,
                hidden_size = hidden_size, 
                hidden_layer_depth = hidden_layer_depth,
                latent_length = latent_length,
                batch_size = batch_size,
                learning_rate = learning_rate,
                n_epochs = n_epochs,
                dropout_rate = dropout_rate,
                cuda = cuda,
                model_name=model_name,
                header=header,
                device = device)

    # TEST before training
    correct = 0
    test_num = 0
    for i, (XI, XB,  y) in enumerate(test_loader):
        if model.header == 'CNN':
            x = XI
        else:
            x = XB
        x, y = x.to(device), y.long().to(device)
        
        if x.size(0) != batch_size:
            print(" test batch {} size {} < {}, skip".format(i, x.size()[0], batch_size))
            break
        test_num += x.size(0)
        x_decoded, latent, output = model(x)

        # compute classification acc
        pred = output.data.max(1, keepdim=True)[1]  # get the index of the max log-probability
        correct += pred.eq(y.data.view_as(pred)).long().cpu().sum().item()

        if i == 0:
            all_latent = latent
            all_y = y
            all_pred = pred
        else:
            all_latent = torch.cat((all_latent, latent), 0)
            all_y = torch.cat((all_y, y), 0)
            all_pred = torch.cat((all_pred, pred), 0)

    # plot latent space and confusion matrix at the start of training
    tsne(all_latent, all_y, 'start')
    confusion_matrix_plot(all_y, all_pred, 'start')
    sio.savemat('save/latent_before_training.mat', {'latent':all_latent})
              
    test_acc = correct / test_num #len(test_loader.dataset)
    print('before training, test accuracy for', str(kfold_number), ' fold : ', test_acc)

    # # load pretrained model
    # model_dir = logDir + model_name + '.pt'
    # model_dict = torch.load(model_dir)
    # model.load_state_dict(model_dict, strict = False)
    # model.to(device)
    # print(model)

    # Initialize training settings
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    cl_loss_fn = nn.NLLLoss()
    recon_loss_fn = nn.MSELoss()


    training_start=datetime.now()
    # create empty lists to fill stats later
    epoch_train_loss = []
    epoch_train_acc = []
    epoch_val_loss = []
    epoch_val_acc = []
    epoch_cl_loss = []
    epoch_rc_loss = []
    max_val_acc = 0

    for epoch in range(n_epochs):
        
        # TRAIN
        model.train()
        correct = 0
        train_loss = 0
        train_num = 0
        for i, (XI, XB,  y) in enumerate(train_loader):
            
            if model.header == 'CNN':
                x = XI
            else:
                x = XB
            x, y = x.to(device), y.long().to(device)
            if x.size()[0] != batch_size:
                break
            
            # reduce data by data_reduction_ratio times
            if i % data_reduction_ratio == 0:
                train_num += x.size(0)
                optimizer.zero_grad()
                # print('X shape:', x.size()) torch.Size([32, 6, 10, 75]) for iCub; torch.Size([32, 19, 400]) for BioTac 
                x_decoded, latent, output = model(x)

                # construct loss function
                # print('output shape', output.size())
                # print('y shape', y.size())
                # print('x_decoded shape', x_decoded.size())
                # print('x shape', x.size())
                # output shape torch.Size([32, 20])
                # y shape torch.Size([32])
                # x_decoded shape torch.Size([32, 19, 1])
                # x shape torch.Size([32, 19, 400])
                cl_loss = cl_loss_fn(output, y)
                recon_loss = recon_loss_fn(x_decoded, x)
                loss = args.w_c*cl_loss + args.w_r *recon_loss
                
                # compute classification acc
                pred = output.data.max(1, keepdim=True)[1]  # get the index of the max log-probability
                correct += pred.eq(y.data.view_as(pred)).long().cpu().sum().item()
                # accumulator
                train_loss += loss.item()
                
                loss.backward()
                optimizer.step()
        
        # if epoch < 20 or epoch%200 == 0:
        print("train last batch {} of {}: cl_loss {:.3f} recon_loss {:.3f}".format(i,len(train_loader),cl_loss, recon_loss))

        # fill stats
        train_accuracy = correct / train_num 
        train_loss /= train_num
        epoch_train_loss.append(train_loss)
        epoch_train_acc.append(train_accuracy) 
        epoch_cl_loss.append(cl_loss)
        epoch_rc_loss.append(recon_loss)
        
        # VALIDATION
        model.eval()
        correct = 0
        val_loss = 0
        val_num = 0
        for i, (XI, XB,  y) in enumerate(val_loader):
            if model.header == 'CNN':
                x = XI
            else:
                x = XB
            x, y = x.to(device), y.long().to(device)
            if x.size()[0] != batch_size:
                break
            val_num += x.size(0)
            x_decoded, latent, output = model(x)

            # construct loss function
            cl_loss = cl_loss_fn(output, y)
            recon_loss = recon_loss_fn(x_decoded, x)
            loss = args.w_c*cl_loss + args.w_r *recon_loss
            
            # compute classification acc
            pred = output.data.max(1, keepdim=True)[1]  # get the index of the max log-probability
            correct += pred.eq(y.data.view_as(pred)).long().cpu().sum().item()
            # accumulator
            val_loss += loss.item()
        
        # fill stats
        val_accuracy = correct / val_num
        val_loss /= val_num
        epoch_val_loss.append(val_loss)  # only save the last batch
        epoch_val_acc.append(val_accuracy)
        
        # if epoch < 20 or epoch%200 == 0:
        print("train_num {}, val_num {}".format(train_num, val_num))
        print('Epoch: {} Loss: train {:.3f}, valid {:.3f}. Accuracy: train: {:.3f}, valid {:.3f}'.format(epoch, train_loss, val_loss, train_accuracy, val_accuracy))
        
        # choose model
        if max_val_acc <= val_accuracy:
            model_dir = logDir + model_name + '.pt'
            print('Saving model at {} epoch to {}'.format(epoch, model_dir))
            max_val_acc = val_accuracy
            torch.save(model.state_dict(), model_dir)

            
    training_end =  datetime.now()
    training_time = training_end -training_start 
    print("training takes time {}".format(training_time))

    model.is_fitted = True
    model.eval()

    # TEST after training
    correct = 0
    test_num = 0
    for i, (XI, XB,  y) in enumerate(test_loader):
        if model.header == 'CNN':
            x = XI
        else:
            x = XB
        x, y = x.to(device), y.long().to(device)
        
        if x.size(0) != batch_size:
            print(" test batch {} size {} < {}, skip".format(i, x.size()[0], batch_size))
            break
        test_num += x.size(0)
        x_decoded, latent, output = model(x)

        # compute classification acc
        pred = output.data.max(1, keepdim=True)[1]  # get the index of the max log-probability
        correct += pred.eq(y.data.view_as(pred)).long().cpu().sum().item()
        
        if i == 0:
            all_latent = latent
            all_y = y
            all_pred = pred
        else:
            all_latent = torch.cat((all_latent, latent), 0)
            all_y = torch.cat((all_y, y), 0)
            all_pred = torch.cat((all_pred, pred), 0)

    # plot latent space and confusion matrix at the start of training
    tsne(all_latent, all_y, 'end')
    confusion_matrix_plot(all_y, all_pred, 'end')
    sio.savemat('save/latent_after_training.mat', {'latent':all_latent})
        
    test_acc = correct / test_num #len(test_loader.dataset)
    print('Test accuracy for', str(kfold_number), ' fold : ', test_acc)

    # Save stats
    results_dict = {"epoch_train_loss": epoch_train_loss,
                    "epoch_train_acc": epoch_train_acc,
                    "epoch_val_loss": epoch_val_loss,
                    "epoch_val_acc": epoch_val_acc,
                    "test_acc": test_acc}

    dict_name = model_name + '_stats_fold{}_{}.pkl'.format(str(kfold_number), args.rep)
    pickle.dump(results_dict, open(logDir + dict_name, 'wb'))
    print("dump results dict to {}".format(dict_name))

    assert n_epochs == len(epoch_train_acc), "different epoch length {} {}".format(n_epochs, len(epoch_train_acc))
    
#     # plot stats
#     fig, ax = plt.subplots(figsize=(15, 7))
#     # data = pd.read_pickle('models_and_stats/test_indiv_B_stats_fold0_0.pkl')
#     # epoch_train_loss = data['epoch_train_loss']
#     ax.plot(epoch_train_loss[:], label='epoch_train_loss')
#     # epoch_train_acc = data['epoch_train_acc']
#     ax.plot(epoch_train_acc[:], label='epoch_train_acc')
#     # epoch_val_loss = data['epoch_val_loss']
#     ax.plot(epoch_val_loss[:], label='epoch_val_loss')
#     # epoch_val_acc = data['epoch_val_acc']
#     ax.plot(epoch_val_acc[:], label='epoch_val_acc')
#     ax.plot(epoch_cl_loss[:], label='epoch_cl_loss')
#     ax.plot(epoch_rc_loss[:], label='epoch_rc_loss')
    
    ax.set_xlabel('epoch')
    ax.set_ylabel('acc')
    ax.grid(True)
    plt.legend(loc='upper right')
    
    # plt.show()
    plt.savefig('save/stats.png')
    if if_plot:
        plt.show()

# if __name__ == "__main__":
#     # Parse argument
#     parser = argparse.ArgumentParser()
#     parser.add_argument("-i", "--rep", type=int, default=0, help='index of running repetition')
#     parser.add_argument('--data_dir', type=str, default='data', help="DIR set in 'gh_download.sh' to store compiled_data")
#     parser.add_argument("-k", "--kfold", type=int, default=0, help="kfold_number for loading data")
#     parser.add_argument("-r", "--reduction", type=int, default=1, help="data reduction ratio for partial training")
#     parser.add_argument("-c", "--cuda", default=0, help="index of cuda gpu to use")
#     parser.add_argument("-d", "--data", type=str, default='B', help="which dataset to use")
#     parser.add_argument("--w_r", type=float, default=0.01, help="weight of reconstructon loss")
#     parser.add_argument("--w_c", type=float, default=1, help="weight of constructon loss")
#     args = parser.parse_args()

#     if args.data == 'I':
#         sequence_length = 75
#         number_of_features = 60
#         header = 'CNN'

#     if args.data == 'B':
#         sequence_length = 400
#         number_of_features = 19
#         header = None
    
#     print(args)
#     train(args, sequence_length, number_of_features, header)
# Out:
# <__main__.Args object at 0x7fb72844f460>

# %% [markdown]
# E1: 40-90-19 no reverse

# %%
train(args, args.sequence_length, args.number_of_features, args.header)
# Out:
# load 0 kfold number, train with full data, put to devide: cpu
# training with BioTac dataset...
#  test batch 6 size 8 < 32, skip
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 192 samples in 0.000s...
# [t-SNE] Computed neighbors for 192 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 192 / 192
# [t-SNE] Mean sigma: 2.186415
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.851376
# [t-SNE] KL divergence after 300 iterations: 1.149957
# before training, test accuracy for 0  fold :  0.052083333333333336
# train last batch 18 of 19: cl_loss 3.020 recon_loss 329.904
# train_num 576, val_num 192
# Epoch: 0 Loss: train 0.206, valid 0.191. Accuracy: train: 0.061, valid 0.057
# Saving model at 0 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.851 recon_loss 297.326
# train_num 576, val_num 192
# Epoch: 1 Loss: train 0.182, valid 0.176. Accuracy: train: 0.118, valid 0.089
# Saving model at 1 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.877 recon_loss 282.367
# train_num 576, val_num 192
# Epoch: 2 Loss: train 0.169, valid 0.166. Accuracy: train: 0.168, valid 0.151
# Saving model at 2 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.678 recon_loss 247.270
# train_num 576, val_num 192
# Epoch: 3 Loss: train 0.159, valid 0.160. Accuracy: train: 0.234, valid 0.198
# Saving model at 3 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.825 recon_loss 210.240
# train_num 576, val_num 192
# Epoch: 4 Loss: train 0.152, valid 0.153. Accuracy: train: 0.264, valid 0.198
# Saving model at 4 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.698 recon_loss 161.921
# train_num 576, val_num 192
# Epoch: 5 Loss: train 0.145, valid 0.148. Accuracy: train: 0.312, valid 0.250
# Saving model at 5 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.554 recon_loss 209.565
# train_num 576, val_num 192
# Epoch: 6 Loss: train 0.141, valid 0.144. Accuracy: train: 0.347, valid 0.276
# Saving model at 6 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.498 recon_loss 170.068
# train_num 576, val_num 192
# Epoch: 7 Loss: train 0.135, valid 0.138. Accuracy: train: 0.359, valid 0.307
# Saving model at 7 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.268 recon_loss 170.696
# train_num 576, val_num 192
# Epoch: 8 Loss: train 0.131, valid 0.135. Accuracy: train: 0.405, valid 0.339
# Saving model at 8 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.205 recon_loss 160.791
# train_num 576, val_num 192
# Epoch: 9 Loss: train 0.127, valid 0.131. Accuracy: train: 0.406, valid 0.318
# train last batch 18 of 19: cl_loss 2.308 recon_loss 184.699
# train_num 576, val_num 192
# Epoch: 10 Loss: train 0.121, valid 0.128. Accuracy: train: 0.469, valid 0.333
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-aed8102304df> in <module>
# ----> 1 train(args, args.sequence_length, args.number_of_features, args.header)
#
# <ipython-input-17-3bd777140a6f> in train(args, sequence_length, number_of_features, header)
#     202                 optimizer.zero_grad()
#     203                 # print('X shape:', x.size()) torch.Size([32, 6, 10, 75]) for iCub; torch.Size([32, 19, 400]) for BioTac
# --> 204                 x_decoded, latent, output = model(x)
#     205
#     206                 # construct loss function
#
# ~/opt/anaconda3/envs/AE/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/Desktop/FYP/ae/code/vrae/lmu.py in forward(self, x)
#     600         if self.header is None:
#     601             h_end, sequence_size = self.encoder(x)
# --> 602         elif self.header == 'CNN':
#     603             h_end, mp_indices, sequence_size = self.encoder(x) # TODO sequence_size, sequence_length
#     604
#
# ~/opt/anaconda3/envs/AE/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/Desktop/FYP/ae/code/vrae/lmu.py in forward(self, x)
#     195         # self.lmu_cell.flatten_parameters()
#     196         for t in range(sequence_size):
# --> 197             h, c = self.lmu_cell(embed_seq[:, t, :], (h, c))
#     198         h_end = h
#     199
#
# ~/opt/anaconda3/envs/AE/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/Desktop/FYP/ae/code/vrae/lmu.py in forward(self, input, hx)
#      92         m = m + F.linear(m, self.AT) + F.linear(u, self.BT)
#      93
# ---> 94         h = self.hidden_activation(
#      95             F.linear(input, self.input_kernel) +
#      96             F.linear(h, self.hidden_kernel) +
#
# KeyboardInterrupt:

# %%
# plot stats
fig, ax = plt.subplots(figsize=(15, 7))
data = pd.read_pickle('models_and_stats/test_indiv_B_stats_fold0_1.pkl')
epoch_train_loss = data['epoch_train_loss']
ax.plot(epoch_train_loss[:], label='epoch_train_loss')
epoch_train_acc = data['epoch_train_acc']
ax.plot(epoch_train_acc[:], label='epoch_train_acc')
epoch_val_loss = data['epoch_val_loss']
ax.plot(epoch_val_loss[:], label='epoch_val_loss')
epoch_val_acc = data['epoch_val_acc']
ax.plot(epoch_val_acc[:], label='epoch_val_acc')

# fig, ax2 = plt.subplots(figsize=(15, 7))
# ax2.plot(epoch_cl_loss[:], label='epoch_cl_loss')
# ax2.plot(epoch_rc_loss[:], label='epoch_rc_loss')
ax.set_xlabel('epoch')
ax.set_ylabel('acc')
ax.grid(True)
plt.legend(loc='upper right')

# %% [markdown]
# E1: 40-90-128-19 no reverse

# %%
train(args, args.sequence_length, args.number_of_features, args.header)

# fig, ax2 = plt.subplots(figsize=(15, 7))
# ax2.plot(epoch_cl_loss[:], label='epoch_cl_loss')
# ax2.plot(epoch_rc_loss[:], label='epoch_rc_loss')
ax.set_xlabel('epoch')
ax.set_ylabel('acc')
ax.grid(True)
plt.legend(loc='upper right')
# Out:
# load 0 kfold number, train with full data, put to devide: cpu
# training with BioTac dataset...
#  test batch 6 size 8 < 32, skip
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 192 samples in 0.001s...
# [t-SNE] Computed neighbors for 192 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 192 / 192
# [t-SNE] Mean sigma: 2.186415
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.851376
# [t-SNE] KL divergence after 300 iterations: 1.149957
# before training, test accuracy for 0  fold :  0.052083333333333336
# train last batch 18 of 19: cl_loss 3.020 recon_loss 329.904
# train_num 576, val_num 192
# Epoch: 0 Loss: train 0.206, valid 0.191. Accuracy: train: 0.061, valid 0.057
# Saving model at 0 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.851 recon_loss 297.326
# train_num 576, val_num 192
# Epoch: 1 Loss: train 0.182, valid 0.176. Accuracy: train: 0.118, valid 0.089
# Saving model at 1 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.877 recon_loss 282.367
# train_num 576, val_num 192
# Epoch: 2 Loss: train 0.169, valid 0.166. Accuracy: train: 0.168, valid 0.151
# Saving model at 2 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.678 recon_loss 247.270
# train_num 576, val_num 192
# Epoch: 3 Loss: train 0.159, valid 0.160. Accuracy: train: 0.234, valid 0.198
# Saving model at 3 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.825 recon_loss 210.240
# train_num 576, val_num 192
# Epoch: 4 Loss: train 0.152, valid 0.153. Accuracy: train: 0.264, valid 0.198
# Saving model at 4 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.698 recon_loss 161.921
# train_num 576, val_num 192
# Epoch: 5 Loss: train 0.145, valid 0.148. Accuracy: train: 0.312, valid 0.250
# Saving model at 5 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.554 recon_loss 209.565
# train_num 576, val_num 192
# Epoch: 6 Loss: train 0.141, valid 0.144. Accuracy: train: 0.347, valid 0.276
# Saving model at 6 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.498 recon_loss 170.068
# train_num 576, val_num 192
# Epoch: 7 Loss: train 0.135, valid 0.138. Accuracy: train: 0.359, valid 0.307
# Saving model at 7 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.268 recon_loss 170.696
# train_num 576, val_num 192
# Epoch: 8 Loss: train 0.131, valid 0.135. Accuracy: train: 0.405, valid 0.339
# Saving model at 8 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.205 recon_loss 160.791
# train_num 576, val_num 192
# Epoch: 9 Loss: train 0.127, valid 0.131. Accuracy: train: 0.406, valid 0.318
# train last batch 18 of 19: cl_loss 2.308 recon_loss 184.699
# train_num 576, val_num 192
# Epoch: 10 Loss: train 0.121, valid 0.128. Accuracy: train: 0.469, valid 0.333
# train last batch 18 of 19: cl_loss 2.073 recon_loss 178.256
# train_num 576, val_num 192
# Epoch: 11 Loss: train 0.116, valid 0.125. Accuracy: train: 0.516, valid 0.333
# train last batch 18 of 19: cl_loss 1.923 recon_loss 157.133
# train_num 576, val_num 192
# Epoch: 12 Loss: train 0.113, valid 0.122. Accuracy: train: 0.512, valid 0.339
# Saving model at 12 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 1.732 recon_loss 127.910
# train_num 576, val_num 192
# Epoch: 13 Loss: train 0.110, valid 0.117. Accuracy: train: 0.524, valid 0.396
# Saving model at 13 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.056 recon_loss 125.382
# train_num 576, val_num 192
# Epoch: 14 Loss: train 0.106, valid 0.115. Accuracy: train: 0.535, valid 0.354
# train last batch 18 of 19: cl_loss 1.915 recon_loss 135.360
# train_num 576, val_num 192
# Epoch: 15 Loss: train 0.102, valid 0.112. Accuracy: train: 0.573, valid 0.422
# Saving model at 15 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 2.071 recon_loss 138.345
# train_num 576, val_num 192
# Epoch: 16 Loss: train 0.100, valid 0.109. Accuracy: train: 0.582, valid 0.432
# Saving model at 16 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 1.772 recon_loss 129.265
# train_num 576, val_num 192
# Epoch: 17 Loss: train 0.098, valid 0.107. Accuracy: train: 0.594, valid 0.391
# train last batch 18 of 19: cl_loss 1.647 recon_loss 136.194
# train_num 576, val_num 192
# Epoch: 18 Loss: train 0.094, valid 0.105. Accuracy: train: 0.616, valid 0.422
# train last batch 18 of 19: cl_loss 1.519 recon_loss 140.517
# train_num 576, val_num 192
# Epoch: 19 Loss: train 0.092, valid 0.102. Accuracy: train: 0.608, valid 0.458
# Saving model at 19 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 1.683 recon_loss 167.288
# train_num 576, val_num 192
# Epoch: 20 Loss: train 0.089, valid 0.102. Accuracy: train: 0.648, valid 0.464
# Saving model at 20 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 1.706 recon_loss 112.492
# train_num 576, val_num 192
# Epoch: 21 Loss: train 0.086, valid 0.099. Accuracy: train: 0.628, valid 0.474
# Saving model at 21 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 1.616 recon_loss 120.302
# train_num 576, val_num 192
# Epoch: 22 Loss: train 0.083, valid 0.097. Accuracy: train: 0.653, valid 0.469
# train last batch 18 of 19: cl_loss 1.633 recon_loss 99.201
# train_num 576, val_num 192
# Epoch: 23 Loss: train 0.083, valid 0.095. Accuracy: train: 0.649, valid 0.474
# Saving model at 23 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 1.111 recon_loss 92.640
# train_num 576, val_num 192
# Epoch: 24 Loss: train 0.079, valid 0.093. Accuracy: train: 0.684, valid 0.484
# Saving model at 24 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 1.377 recon_loss 94.222
# train_num 576, val_num 192
# Epoch: 25 Loss: train 0.078, valid 0.092. Accuracy: train: 0.684, valid 0.505
# Saving model at 25 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 1.069 recon_loss 105.708
# train_num 576, val_num 192
# Epoch: 26 Loss: train 0.074, valid 0.090. Accuracy: train: 0.717, valid 0.495
# train last batch 18 of 19: cl_loss 1.480 recon_loss 85.589
# train_num 576, val_num 192
# Epoch: 27 Loss: train 0.074, valid 0.089. Accuracy: train: 0.700, valid 0.505
# Saving model at 27 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 1.213 recon_loss 138.323
# train_num 576, val_num 192
# Epoch: 28 Loss: train 0.072, valid 0.088. Accuracy: train: 0.703, valid 0.495
# train last batch 18 of 19: cl_loss 1.173 recon_loss 89.747
# train_num 576, val_num 192
# Epoch: 29 Loss: train 0.072, valid 0.086. Accuracy: train: 0.688, valid 0.505
# Saving model at 29 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 1.312 recon_loss 86.337
# train_num 576, val_num 192
# Epoch: 30 Loss: train 0.069, valid 0.085. Accuracy: train: 0.701, valid 0.510
# Saving model at 30 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 1.044 recon_loss 96.567
# train_num 576, val_num 192
# Epoch: 31 Loss: train 0.068, valid 0.085. Accuracy: train: 0.712, valid 0.510
# Saving model at 31 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 1.292 recon_loss 97.261
# train_num 576, val_num 192
# Epoch: 32 Loss: train 0.068, valid 0.084. Accuracy: train: 0.703, valid 0.495
# train last batch 18 of 19: cl_loss 1.291 recon_loss 65.502
# train_num 576, val_num 192
# Epoch: 33 Loss: train 0.067, valid 0.083. Accuracy: train: 0.700, valid 0.510
# Saving model at 33 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 0.863 recon_loss 86.765
# train_num 576, val_num 192
# Epoch: 34 Loss: train 0.064, valid 0.081. Accuracy: train: 0.731, valid 0.526
# Saving model at 34 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 0.974 recon_loss 88.894
# train_num 576, val_num 192
# Epoch: 35 Loss: train 0.061, valid 0.081. Accuracy: train: 0.773, valid 0.521
# train last batch 18 of 19: cl_loss 0.987 recon_loss 118.960
# train_num 576, val_num 192
# Epoch: 36 Loss: train 0.062, valid 0.078. Accuracy: train: 0.733, valid 0.542
# Saving model at 36 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 1.191 recon_loss 80.523
# train_num 576, val_num 192
# Epoch: 37 Loss: train 0.060, valid 0.079. Accuracy: train: 0.752, valid 0.536
# train last batch 18 of 19: cl_loss 0.939 recon_loss 90.431
# train_num 576, val_num 192
# Epoch: 38 Loss: train 0.060, valid 0.077. Accuracy: train: 0.745, valid 0.531
# train last batch 18 of 19: cl_loss 0.935 recon_loss 96.048
# train_num 576, val_num 192
# Epoch: 39 Loss: train 0.060, valid 0.078. Accuracy: train: 0.747, valid 0.536
# train last batch 18 of 19: cl_loss 0.851 recon_loss 81.493
# train_num 576, val_num 192
# Epoch: 40 Loss: train 0.056, valid 0.076. Accuracy: train: 0.776, valid 0.557
# Saving model at 40 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 1.208 recon_loss 92.516
# train_num 576, val_num 192
# Epoch: 41 Loss: train 0.057, valid 0.075. Accuracy: train: 0.760, valid 0.547
# train last batch 18 of 19: cl_loss 0.952 recon_loss 86.776
# train_num 576, val_num 192
# Epoch: 42 Loss: train 0.057, valid 0.075. Accuracy: train: 0.762, valid 0.531
# train last batch 18 of 19: cl_loss 0.611 recon_loss 86.188
# train_num 576, val_num 192
# Epoch: 43 Loss: train 0.055, valid 0.076. Accuracy: train: 0.785, valid 0.547
# train last batch 18 of 19: cl_loss 1.291 recon_loss 96.160
# train_num 576, val_num 192
# Epoch: 44 Loss: train 0.054, valid 0.075. Accuracy: train: 0.774, valid 0.562
# Saving model at 44 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 0.860 recon_loss 80.898
# train_num 576, val_num 192
# Epoch: 45 Loss: train 0.054, valid 0.073. Accuracy: train: 0.773, valid 0.557
# train last batch 18 of 19: cl_loss 0.522 recon_loss 66.609
# train_num 576, val_num 192
# Epoch: 46 Loss: train 0.051, valid 0.072. Accuracy: train: 0.783, valid 0.562
# Saving model at 46 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 0.795 recon_loss 59.024
# train_num 576, val_num 192
# Epoch: 47 Loss: train 0.051, valid 0.072. Accuracy: train: 0.767, valid 0.557
# train last batch 18 of 19: cl_loss 0.975 recon_loss 56.169
# train_num 576, val_num 192
# Epoch: 48 Loss: train 0.052, valid 0.071. Accuracy: train: 0.747, valid 0.552
# train last batch 18 of 19: cl_loss 1.131 recon_loss 71.023
# train_num 576, val_num 192
# Epoch: 49 Loss: train 0.049, valid 0.070. Accuracy: train: 0.785, valid 0.557
# train last batch 18 of 19: cl_loss 1.029 recon_loss 70.269
# train_num 576, val_num 192
# Epoch: 50 Loss: train 0.048, valid 0.069. Accuracy: train: 0.785, valid 0.568
# Saving model at 50 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 0.659 recon_loss 84.091
# train_num 576, val_num 192
# Epoch: 51 Loss: train 0.050, valid 0.069. Accuracy: train: 0.740, valid 0.552
# train last batch 18 of 19: cl_loss 0.734 recon_loss 70.500
# train_num 576, val_num 192
# Epoch: 52 Loss: train 0.046, valid 0.068. Accuracy: train: 0.778, valid 0.531
# train last batch 18 of 19: cl_loss 0.896 recon_loss 64.405
# train_num 576, val_num 192
# Epoch: 53 Loss: train 0.045, valid 0.068. Accuracy: train: 0.804, valid 0.557
# train last batch 18 of 19: cl_loss 0.449 recon_loss 62.673
# train_num 576, val_num 192
# Epoch: 54 Loss: train 0.047, valid 0.069. Accuracy: train: 0.757, valid 0.547
# train last batch 18 of 19: cl_loss 0.810 recon_loss 63.027
# train_num 576, val_num 192
# Epoch: 55 Loss: train 0.042, valid 0.066. Accuracy: train: 0.809, valid 0.583
# Saving model at 55 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 0.643 recon_loss 115.826
# train_num 576, val_num 192
# Epoch: 56 Loss: train 0.042, valid 0.067. Accuracy: train: 0.797, valid 0.568
# train last batch 18 of 19: cl_loss 0.938 recon_loss 89.936
# train_num 576, val_num 192
# Epoch: 57 Loss: train 0.044, valid 0.066. Accuracy: train: 0.774, valid 0.552
# train last batch 18 of 19: cl_loss 0.613 recon_loss 54.014
# train_num 576, val_num 192
# Epoch: 58 Loss: train 0.041, valid 0.066. Accuracy: train: 0.806, valid 0.573
# train last batch 18 of 19: cl_loss 0.845 recon_loss 59.615
# train_num 576, val_num 192
# Epoch: 59 Loss: train 0.043, valid 0.063. Accuracy: train: 0.773, valid 0.573
# train last batch 18 of 19: cl_loss 0.501 recon_loss 59.932
# train_num 576, val_num 192
# Epoch: 60 Loss: train 0.042, valid 0.065. Accuracy: train: 0.778, valid 0.583
# Saving model at 60 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 0.883 recon_loss 72.316
# train_num 576, val_num 192
# Epoch: 61 Loss: train 0.041, valid 0.064. Accuracy: train: 0.797, valid 0.562
# train last batch 18 of 19: cl_loss 0.380 recon_loss 66.488
# train_num 576, val_num 192
# Epoch: 62 Loss: train 0.040, valid 0.065. Accuracy: train: 0.800, valid 0.573
# train last batch 18 of 19: cl_loss 0.769 recon_loss 65.371
# train_num 576, val_num 192
# Epoch: 63 Loss: train 0.042, valid 0.064. Accuracy: train: 0.755, valid 0.562
# train last batch 18 of 19: cl_loss 0.631 recon_loss 42.575
# train_num 576, val_num 192
# Epoch: 64 Loss: train 0.040, valid 0.063. Accuracy: train: 0.786, valid 0.562
# train last batch 18 of 19: cl_loss 0.621 recon_loss 58.787
# train_num 576, val_num 192
# Epoch: 65 Loss: train 0.039, valid 0.064. Accuracy: train: 0.795, valid 0.583
# Saving model at 65 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 0.641 recon_loss 56.919
# train_num 576, val_num 192
# Epoch: 66 Loss: train 0.039, valid 0.064. Accuracy: train: 0.788, valid 0.578
# train last batch 18 of 19: cl_loss 0.666 recon_loss 57.155
# train_num 576, val_num 192
# Epoch: 67 Loss: train 0.039, valid 0.064. Accuracy: train: 0.785, valid 0.557
# train last batch 18 of 19: cl_loss 0.715 recon_loss 87.811
# train_num 576, val_num 192
# Epoch: 68 Loss: train 0.038, valid 0.064. Accuracy: train: 0.788, valid 0.557
# train last batch 18 of 19: cl_loss 0.489 recon_loss 56.509
# train_num 576, val_num 192
# Epoch: 69 Loss: train 0.039, valid 0.063. Accuracy: train: 0.781, valid 0.568
# train last batch 18 of 19: cl_loss 0.621 recon_loss 67.488
# train_num 576, val_num 192
# Epoch: 70 Loss: train 0.038, valid 0.061. Accuracy: train: 0.786, valid 0.562
# train last batch 18 of 19: cl_loss 0.464 recon_loss 87.999
# train_num 576, val_num 192
# Epoch: 71 Loss: train 0.036, valid 0.063. Accuracy: train: 0.807, valid 0.552
# train last batch 18 of 19: cl_loss 1.035 recon_loss 59.608
# train_num 576, val_num 192
# Epoch: 72 Loss: train 0.037, valid 0.062. Accuracy: train: 0.786, valid 0.562
# train last batch 18 of 19: cl_loss 0.317 recon_loss 72.863
# train_num 576, val_num 192
# Epoch: 73 Loss: train 0.035, valid 0.063. Accuracy: train: 0.823, valid 0.557
# train last batch 18 of 19: cl_loss 0.623 recon_loss 55.029
# train_num 576, val_num 192
# Epoch: 74 Loss: train 0.037, valid 0.063. Accuracy: train: 0.790, valid 0.547
# train last batch 18 of 19: cl_loss 0.459 recon_loss 52.739
# train_num 576, val_num 192
# Epoch: 75 Loss: train 0.035, valid 0.063. Accuracy: train: 0.802, valid 0.552
# train last batch 18 of 19: cl_loss 0.434 recon_loss 51.349
# train_num 576, val_num 192
# Epoch: 76 Loss: train 0.036, valid 0.062. Accuracy: train: 0.797, valid 0.568
# train last batch 18 of 19: cl_loss 0.470 recon_loss 51.622
# train_num 576, val_num 192
# Epoch: 77 Loss: train 0.035, valid 0.060. Accuracy: train: 0.809, valid 0.573
# train last batch 18 of 19: cl_loss 0.366 recon_loss 39.326
# train_num 576, val_num 192
# Epoch: 78 Loss: train 0.034, valid 0.060. Accuracy: train: 0.802, valid 0.562
# train last batch 18 of 19: cl_loss 0.636 recon_loss 61.026
# train_num 576, val_num 192
# Epoch: 79 Loss: train 0.033, valid 0.063. Accuracy: train: 0.825, valid 0.552
# train last batch 18 of 19: cl_loss 0.466 recon_loss 61.028
# train_num 576, val_num 192
# Epoch: 80 Loss: train 0.034, valid 0.062. Accuracy: train: 0.821, valid 0.531
# train last batch 18 of 19: cl_loss 0.620 recon_loss 50.595
# train_num 576, val_num 192
# Epoch: 81 Loss: train 0.034, valid 0.062. Accuracy: train: 0.807, valid 0.552
# train last batch 18 of 19: cl_loss 0.334 recon_loss 60.137
# train_num 576, val_num 192
# Epoch: 82 Loss: train 0.034, valid 0.061. Accuracy: train: 0.814, valid 0.562
# train last batch 18 of 19: cl_loss 0.443 recon_loss 56.895
# train_num 576, val_num 192
# Epoch: 83 Loss: train 0.033, valid 0.061. Accuracy: train: 0.828, valid 0.568
# train last batch 18 of 19: cl_loss 0.640 recon_loss 54.680
# train_num 576, val_num 192
# Epoch: 84 Loss: train 0.033, valid 0.061. Accuracy: train: 0.809, valid 0.578
# train last batch 18 of 19: cl_loss 0.539 recon_loss 72.493
# train_num 576, val_num 192
# Epoch: 85 Loss: train 0.033, valid 0.061. Accuracy: train: 0.825, valid 0.583
# Saving model at 85 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 0.463 recon_loss 68.861
# train_num 576, val_num 192
# Epoch: 86 Loss: train 0.032, valid 0.060. Accuracy: train: 0.826, valid 0.589
# Saving model at 86 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 0.784 recon_loss 45.974
# train_num 576, val_num 192
# Epoch: 87 Loss: train 0.033, valid 0.061. Accuracy: train: 0.806, valid 0.589
# Saving model at 87 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 0.467 recon_loss 54.836
# train_num 576, val_num 192
# Epoch: 88 Loss: train 0.030, valid 0.061. Accuracy: train: 0.845, valid 0.583
# train last batch 18 of 19: cl_loss 0.568 recon_loss 38.272
# train_num 576, val_num 192
# Epoch: 89 Loss: train 0.031, valid 0.061. Accuracy: train: 0.837, valid 0.568
# train last batch 18 of 19: cl_loss 0.717 recon_loss 40.485
# train_num 576, val_num 192
# Epoch: 90 Loss: train 0.032, valid 0.061. Accuracy: train: 0.821, valid 0.578
# train last batch 18 of 19: cl_loss 0.402 recon_loss 63.257
# train_num 576, val_num 192
# Epoch: 91 Loss: train 0.031, valid 0.060. Accuracy: train: 0.819, valid 0.604
# Saving model at 91 epoch to models_and_stats/test_indiv_B.pt
# train last batch 18 of 19: cl_loss 0.570 recon_loss 55.557
# train_num 576, val_num 192
# Epoch: 92 Loss: train 0.031, valid 0.060. Accuracy: train: 0.826, valid 0.562
# train last batch 18 of 19: cl_loss 0.540 recon_loss 38.767
# train_num 576, val_num 192
# Epoch: 93 Loss: train 0.030, valid 0.060. Accuracy: train: 0.851, valid 0.599
# train last batch 18 of 19: cl_loss 0.565 recon_loss 50.231
# train_num 576, val_num 192
# Epoch: 94 Loss: train 0.031, valid 0.060. Accuracy: train: 0.804, valid 0.594
# train last batch 18 of 19: cl_loss 0.284 recon_loss 37.823
# train_num 576, val_num 192
# Epoch: 95 Loss: train 0.030, valid 0.058. Accuracy: train: 0.832, valid 0.578
# train last batch 18 of 19: cl_loss 0.510 recon_loss 32.282
# train_num 576, val_num 192
# Epoch: 96 Loss: train 0.030, valid 0.060. Accuracy: train: 0.837, valid 0.589
# train last batch 18 of 19: cl_loss 0.326 recon_loss 36.867
# train_num 576, val_num 192
# Epoch: 97 Loss: train 0.030, valid 0.059. Accuracy: train: 0.819, valid 0.573
# train last batch 18 of 19: cl_loss 0.506 recon_loss 53.713
# train_num 576, val_num 192
# Epoch: 98 Loss: train 0.028, valid 0.059. Accuracy: train: 0.840, valid 0.578
# train last batch 18 of 19: cl_loss 0.507 recon_loss 48.820
# train_num 576, val_num 192
# Epoch: 99 Loss: train 0.030, valid 0.060. Accuracy: train: 0.819, valid 0.583
# training takes time 0:15:50.019659
#  test batch 6 size 8 < 32, skip
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 192 samples in 0.000s...
# [t-SNE] Computed neighbors for 192 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 192 / 192
# [t-SNE] Mean sigma: 4.411426
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 58.248299
# [t-SNE] KL divergence after 300 iterations: 0.935612
# Test accuracy for 0  fold :  0.5833333333333334
# dump results dict to test_indiv_B_stats_fold0_1.pkl

# %%
# plot stats
fig, ax = plt.subplots(figsize=(15, 7))
data = pd.read_pickle('models_and_stats/test_indiv_B_stats_fold0_1.pkl')
epoch_train_loss = data['epoch_train_loss']
ax.plot(epoch_train_loss[:], label='epoch_train_loss')
epoch_train_acc = data['epoch_train_acc']
ax.plot(epoch_train_acc[:], label='epoch_train_acc')
epoch_val_loss = data['epoch_val_loss']
ax.plot(epoch_val_loss[:], label='epoch_val_loss')
epoch_val_acc = data['epoch_val_acc']
ax.plot(epoch_val_acc[:], label='epoch_val_acc')
