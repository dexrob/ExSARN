# %%
# plot B10
from vrae.tas_utils_bs import get_trainValLoader, get_testLoader
import numpy as np
kfold_number = 0
batch_size = 1
shuffle = True
data_dir = 'data/compiled_data/'
train_loader, val_loader, train_dataset, val_dataset = get_trainValLoader(data_dir, k=kfold_number, spike_ready=False, batch_size=batch_size, shuffle=shuffle)
test_loader, test_dataset = get_testLoader(data_dir, spike_ready=False, batch_size=batch_size, shuffle=shuffle)

# %%
for i, (xi, xb, y) in enumerate(train_loader):
#     print(xi.size()) # 1, 6, 10, 75
#     print(xb.size()) # 1, 19, 400
    if i != 0:
        break
    print(y)
    xb = xb[0,10,:].squeeze().detach().numpy()
    xi = xi[0,3,5,:].detach().numpy()
# Out:
# tensor([6.])

# %%
np.shape(xb)
# Out:
# torch.Size([1, 19, 400])

# %%
import matplotlib.pyplot as plt
plt.plot(xb)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-d1435379c782> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(xb)
#
# ~/opt/anaconda3/envs/AE/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2822 @_copy_docstring_and_deprecators(Axes.plot)
#    2823 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2824     return gca().plot(
#    2825         *args, scalex=scalex, scaley=scaley,
#    2826         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/opt/anaconda3/envs/AE/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/opt/anaconda3/envs/AE/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~/opt/anaconda3/envs/AE/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
# --> 402             raise ValueError(f"x and y can be no greater than 2-D, but have "
#     403                              f"shapes {x.shape} and {y.shape}")
#     404         if x.ndim == 1:
#
# ValueError: x and y can be no greater than 2-D, but have shapes (1,) and torch.Size([1, 19, 400])

# %%
plt.plot(xi)
